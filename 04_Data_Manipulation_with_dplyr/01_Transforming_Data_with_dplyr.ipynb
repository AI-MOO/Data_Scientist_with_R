# %% [markdown]
# # Section 01: Transforming Data with dplyr
# ### `01- Selecting columns`
# Select the following four columns from the counties variable:
#
# - state
# - county
# - population
# - poverty
#
# You don't need to save the result to a variable.
# - Select the columns listed from the counties variable.

# %%
library(dplyr)
counties <- read.csv("C:\\Users\\mosman\\Desktop\\Github\\Data_Scientist_with_R\\00_Datasets\\counties.csv", 
                    header=TRUE)

# %%
counties %>%
  # Select the columns
  select(state, county, population, poverty)
# Out:
#      state     county        population poverty
# 1    Alabama   "Autauga"      55221     12.9
# 2    Alabama   "Baldwin"     195121     13.4
# 3    Alabama   "Barbour"      26932     26.7
# 4    Alabama   "Bibb"         22604     16.8
# 5    Alabama   "Blount"       57710     16.7
# 6    Alabama   "Bullock"      10678     24.6
# 7    Alabama   "Butler"       20354     25.4
# 8    Alabama   "Calhoun"     116648     20.5
# 9    Alabama   "Chambers"     34079     21.6
# 10   Alabama   "Cherokee"     26008     19.2
# 11   Alabama   "Chilton"      43819     19.1
# 12   Alabama   "Choctaw"      13395     23.4
# 13   Alabama   "Clarke"       25070     24.7
# 14   Alabama   "Clay"         13537     16.7
# 15   Alabama   "Cleburne"     15002     17.0
# 16   Alabama   "Coffee"       50884     17.1
# 17   Alabama   "Colbert"      54444     17.4
# 18   Alabama   "Conecuh"      12865     33.8
# 19   Alabama   "Coosa"        11027     19.3
# 20   Alabama   "Covington"    37886     20.2
# 21   Alabama   "Crenshaw"     13938     16.7
# 22   Alabama   "Cullman"      80965     18.5
# 23   Alabama   "Dale"         49866     19.1
# 24   Alabama   "Dallas"       42154     35.0
# 25   Alabama   "DeKalb"       71068     18.7
# 26   Alabama   "Elmore"       80763     13.6
# 27   Alabama   "Escambia"     37935     24.2
# 28   Alabama   "Etowah"      103766     19.7
# 29   Alabama   "Fayette"      16896     18.3
# 30   Alabama   "Franklin"     31634     22.5
# ⋮    ⋮         ⋮             ⋮          ⋮
# 3109 Wisconsin "Washburn"     15700     13.1
# 3110 Wisconsin "Washington"  132921      5.6
# 3111 Wisconsin "Waukesha"    393873      5.3
# 3112 Wisconsin "Waupaca"      52125     10.4
# 3113 Wisconsin "Waushara"     24321     10.3
# 3114 Wisconsin "Winnebago"   169004     12.0
# 3115 Wisconsin "Wood"         74012     11.0
# 3116 Wyoming   "Albany"       37565     26.9
# 3117 Wyoming   "Big Horn"     11895     12.1
# 3118 Wyoming   "Campbell"     48013      7.2
# 3119 Wyoming   "Carbon"       15739     15.3
# 3120 Wyoming   "Converse"     14101      9.4
# 3121 Wyoming   "Crook"         7229      5.0
# 3122 Wyoming   "Fremont"      40755     14.2
# 3123 Wyoming   "Goshen"       13544     17.9
# 3124 Wyoming   "Hot Springs"   4809     10.7
# 3125 Wyoming   "Johnson"       8600      6.3
# 3126 Wyoming   "Laramie"      95431     10.1
# 3127 Wyoming   "Lincoln"      18316      7.9
# 3128 Wyoming   "Natrona"      80011     10.7
# 3129 Wyoming   "Niobrara"      2516     14.9
# 3130 Wyoming   "Park"         28985      7.2
# 3131 Wyoming   "Platte"        8750     16.1
# 3132 Wyoming   "Sheridan"     29738      8.3
# 3133 Wyoming   "Sublette"     10117      8.1
# 3134 Wyoming   "Sweetwater"   44772     11.5
# 3135 Wyoming   "Teton"        22311      7.4
# 3136 Wyoming   "Uinta"        20930     13.7
# 3137 Wyoming   "Washakie"      8400     13.8
# 3138 Wyoming   "Weston"        7152     14.1

# %% [markdown]
# ### `02-Arranging observations`
# - Add a verb to sort the observations of the `public_work` variable in descending order.

# %%
counties_selected <- counties %>%
  select(state, county, population, private_work, public_work, self_employed)

counties_selected %>%
  # Add a verb to sort in descending order of public_work
  arrange(desc(public_work))
# Out:
#      state      county                       population private_work
# 1    Hawaii     "Kalawao"                       85      25.0
# 2    Alaska     "Yukon-Koyukuk Census Area"   5644      33.3
# 3    Wisconsin  "Menominee"                   4451      36.8
# 4    North Dako ta   "Sioux"                  4380      32.9
# 5    South Dako ta   "Todd"                   9942      34.4
# 6    Alaska     "Lake and Peninsula Borough"  1474      42.2
# 7    California "Lassen"                     32645      42.6
# 8    South Dako ta   "Buffalo"                2038      48.4
# 9    South Dako ta   "Dewey"                  5579      34.9
# 10   Texas      "Kenedy"                       565      51.9
# 11   North Dako ta   "Rolette"               14498      44.3
# 12   Arizona    "Apache"                     72124      50.2
# 13   Alaska     "Bethel Census Area"         17776      53.2
# 14   Utah       "Daggett"                      776      47.7
# 15   Alaska     "Nome Census Area"            9854      50.6
# 16   New Mexico "Mora"                        4660      50.7
# 17   Alaska     "Northwest Arctic Borough"    7732      54.0
# 18   Montana    "Big Horn"                   13141      47.7
# 19   Nevada     "Lincoln"                     5194      50.1
# 20   South Dako ta   "Jackson"                3237      34.1
# 21   New Mexico "Harding"                      565      46.3
# 22   Montana    "Roosevelt"                  11072      45.0
# 23   California "Sierra"                      3021      45.0
# 24   Georgia    "Calhoun"                     6489      53.2
# 25   South Dako ta   "Ziebach"                2833      40.9
# 26   South Dako ta   "Corson"                 4149      36.1
# 27   Washington "Ferry"                       7652      52.4
# 28   Texas      "Brewster"                    9235      49.2
# 29   South Dako ta   "Mellette"               2086      37.3
# 30   New Mexico "Catron"                      3583      50.3
# ⋮    ⋮          ⋮                            ⋮          ⋮
# 3109 North Dako ta   "Steele"                  1979     72.8
# 3110 Pennsylvan ia   "Chester"               509797     85.9
# 3111 Pennsylvan ia   "Lehigh"                356756     87.0
# 3112 Wisconsin  "Ozaukee"                     87273     85.5
# 3113 Indiana    "Dubois"                      42291     87.1
# 3114 Iowa       "Carroll"                     20629     81.5
# 3115 Missouri   "Taney"                       53555     82.8
# 3116 Illinois   "Edwards"                      6649     85.8
# 3117 Pennsylvan ia   "Wyoming"                28147     85.1
# 3118 Wisconsin  "Waukesha"                   393873     87.4
# 3119 Michigan   "Allegan"                    112837     85.2
# 3120 Nebraska   "Colfax"                      10522     83.3
# 3121 Pennsylvan ia   "Lancaster"             530216     84.7
# 3122 Wisconsin  "Washington"                 132921     87.7
# 3123 Pennsylvan ia   "Montgomery"            812970     86.2
# 3124 Arkansas   "Benton"                     238198     85.9
# 3125 Iowa       "Winnebago"                   10614     84.3
# 3126 Indiana    "Elkhart"                    200685     87.5
# 3127 Indiana    "Gibson"                      33668     88.0
# 3128 Michigan   "Kent"                       622590     87.3
# 3129 Pennsylvan ia   "Elk"                    31370     87.1
# 3130 Indiana    "Bartholomew"                 79488     87.8
# 3131 Illinois   "Jersey"                      22625     86.6
# 3132 Indiana    "Clinton"                     32835     87.5
# 3133 Nebraska   "Dakota"                      20798     87.3
# 3134 Indiana    "Kosciusko"                   77983     88.3
# 3135 Indiana    "Spencer"                     20856     86.3
# 3136 Indiana    "LaGrange"                    38084     84.1
# 3137 Nebraska   "McPherson"                     433     69.4
# 3138 Ohio       "Holmes"                      43436     81.3
#      public_work self_employed
# 1    64.1        10.9
# 2    61.7         5.1
# 3    59.1         3.7
# 4    56.8        10.2
# 5    55.0         9.8
# 6    51.6         6.1
# 7    50.5         6.8
# 8    49.5         1.8
# 9    49.2        14.7
# 10   48.1         0.0
# 11   46.6         8.7
# 12   45.0         4.7
# 13   44.8         2.0
# 14   44.1         8.1
# 15   44.0         5.2
# 16   43.9         5.2
# 17   43.7         2.1
# 18   43.2         8.7
# 19   43.1         6.6
# 20   43.1        21.5
# 21   42.9        10.7
# 22   42.8        11.3
# 23   42.3         9.7
# 24   42.3         4.4
# 25   41.7        16.6
# 26   40.8        21.5
# 27   40.6         6.4
# 28   40.4         9.0
# 29   39.9        22.4
# 30   39.7         8.3
# ⋮    ⋮           ⋮
# 3109 8.5         18.1
# 3110 8.5          5.5
# 3111 8.5          4.4
# 3112 8.5          5.7
# 3113 8.4          4.4
# 3114 8.4         10.0
# 3115 8.4          8.8
# 3116 8.3          5.9
# 3117 8.3          6.4
# 3118 8.3          4.2
# 3119 8.2          6.4
# 3120 8.2          8.3
# 3121 8.2          6.8
# 3122 8.2          4.1
# 3123 8.1          5.5
# 3124 8.0          5.9
# 3125 7.9          7.5
# 3126 7.7          4.6
# 3127 7.7          4.2
# 3128 7.7          4.9
# 3129 7.7          4.9
# 3130 7.6          4.5
# 3131 7.5          5.8
# 3132 7.5          4.9
# 3133 7.3          5.2
# 3134 6.9          4.7
# 3135 6.9          6.7
# 3136 6.6          8.7
# 3137 5.9         23.9
# 3138 5.8         12.3

# %% [markdown]
# ### `03-Filtering for conditions`
# - Find only the counties that have a population above one million (1000000).

# %%
counties_selected <- counties %>%
  select(state, county, population)

counties_selected %>%
  # Filter for counties with a population above 1000000
  filter(population > 1000000)
# Out:
#    state      county              population
# 1  Arizona    "Maricopa"           4018143
# 2  California "Alameda"            1584983
# 3  California "Contra Costa"       1096068
# 4  California "Los Angeles"       10038388
# 5  California "Orange"             3116069
# 6  California "Riverside"          2298032
# 7  California "Sacramento"         1465832
# 8  California "San Bernardino"     2094769
# 9  California "San Diego"          3223096
# 10 California "Santa Clara"        1868149
# 11 Florida    "Broward"            1843152
# 12 Florida    "Hillsborough"       1302884
# 13 Florida    "Miami-Dade"         2639042
# 14 Florida    "Orange"             1229039
# 15 Florida    "Palm Beach"         1378806
# 16 Illinois   "Cook"               5236393
# 17 Maryland   "Montgomery"         1017859
# 18 Massachuse tts  "Middlesex"     1556116
# 19 Michigan   "Oakland"            1229503
# 20 Michigan   "Wayne"              1778969
# 21 Minnesota  "Hennepin"           1197776
# 22 Missouri   "St. Louis"          1001327
# 23 Nevada     "Clark"              2035572
# 24 New York   "Bronx"              1428357
# 25 New York   "Kings"              2595259
# 26 New York   "Nassau"             1354612
# 27 New York   "New York"           1629507
# 28 New York   "Queens"             2301139
# 29 New York   "Suffolk"            1501373
# 30 Ohio       "Cuyahoga"           1263189
# 31 Ohio       "Franklin"           1215761
# 32 Pennsylvan ia   "Allegheny"     1231145
# 33 Pennsylvan ia   "Philadelphia"  1555072
# 34 Texas      "Bexar"              1825502
# 35 Texas      "Dallas"             2485003
# 36 Texas      "Harris"             4356362
# 37 Texas      "Tarrant"            1914526
# 38 Texas      "Travis"             1121645
# 39 Utah       "Salt Lake"          1078958
# 40 Virginia   "Fairfax"            1128722
# 41 Washington "King"               2045756

# %% [markdown]
# - Find only the counties in the state of California that also have a population above one million (`1000000`).

# %%
counties_selected <- counties %>%
  select(state, county, population)

counties_selected %>%
  # Filter for counties with a population above 1000000
  filter(state == "California", population > 1000000)
# Out:
#   state      county           population
# 1 California "Alameda"         1584983
# 2 California "Contra Costa"    1096068
# 3 California "Los Angeles"    10038388
# 4 California "Orange"          3116069
# 5 California "Riverside"       2298032
# 6 California "Sacramento"      1465832
# 7 California "San Bernardino"  2094769
# 8 California "San Diego"       3223096
# 9 California "Santa Clara"     1868149

# %% [markdown]
#  ### `04-Filtering and arranging`
#
# - Filter for counties in the state of Texas that have more than ten thousand people (`10000`), and sort them in descending order of the percentage of people employed in private work.

# %%
counties_selected <- counties %>%
  select(state, county, population, private_work, public_work, self_employed)

# Filter for Texas and more than 10000 people; sort in descending order of private_work
counties_selected %>%
  # Filter for Texas and more than 10000 people
  filter(state == "Texas", population > 10000) %>%
  # Sort in descending order of private_work
  arrange(desc(private_work))
# Out:
#     state county        population private_work public_work self_employed
# 1   Texas "Gregg"        123178    84.7          9.8        5.4
# 2   Texas "Collin"       862215    84.1         10.0        5.8
# 3   Texas "Dallas"      2485003    83.9          9.5        6.4
# 4   Texas "Harris"      4356362    83.4         10.1        6.3
# 5   Texas "Andrews"       16775    83.1          9.6        6.8
# 6   Texas "Tarrant"     1914526    83.1         11.4        5.4
# 7   Texas "Titus"         32553    82.5         10.0        7.4
# 8   Texas "Denton"       731851    82.2         11.9        5.7
# 9   Texas "Ector"        149557    82.0         11.2        6.7
# 10  Texas "Moore"         22281    82.0         11.7        5.9
# 11  Texas "Jefferson"    252872    81.9         13.4        4.5
# 12  Texas "Fort Bend"    658331    81.7         12.5        5.7
# 13  Texas "Panola"        23900    81.5         11.7        6.9
# 14  Texas "Midland"      151290    81.2         11.4        7.1
# 15  Texas "Potter"       122352    81.2         12.4        6.2
# 16  Texas "Frio"          18168    81.1         15.4        3.4
# 17  Texas "Johnson"      155450    80.9         13.3        5.7
# 18  Texas "Smith"        217552    80.9         12.7        6.3
# 19  Texas "Orange"        83217    80.8         13.7        5.4
# 20  Texas "Harrison"      66417    80.6         13.9        5.4
# 21  Texas "Brazoria"     331741    80.5         14.4        5.0
# 22  Texas "Calhoun"       21666    80.5         12.8        6.7
# 23  Texas "Austin"        28886    80.4         11.8        7.7
# 24  Texas "Montgomery"   502586    80.4         11.7        7.8
# 25  Texas "Jim Wells"     41461    80.3         12.6        7.1
# 26  Texas "Hutchinson"    21858    80.2         13.9        5.8
# 27  Texas "Ochiltree"     10642    80.1         10.4        9.2
# 28  Texas "Victoria"      90099    80.1         12.5        7.1
# 29  Texas "Hardin"        55375    80.0         15.7        4.2
# 30  Texas "Bexar"       1825502    79.6         14.8        5.6
# ⋮   ⋮     ⋮             ⋮          ⋮            ⋮           ⋮
# 140 Texas "Robertson"    16532     69.8         22.4         7.6
# 141 Texas "Karnes"       14879     69.6         22.0         7.8
# 142 Texas "Kleberg"      32029     69.5         25.9         4.4
# 143 Texas "Burleson"     17293     69.4         21.7         8.4
# 144 Texas "Leon"         16819     69.4         14.5        15.7
# 145 Texas "Bandera"      20796     69.2         19.0        11.6
# 146 Texas "Bell"        326041     69.2         25.7         5.0
# 147 Texas "San Jacinto"  27023     69.1         23.0         7.6
# 148 Texas "Maverick"     56548     68.8         25.0         6.1
# 149 Texas "Trinity"      14405     68.8         17.8        12.1
# 150 Texas "Jones"        19978     68.7         20.5        10.3
# 151 Texas "Polk"         46113     68.7         22.2         8.7
# 152 Texas "Pecos"        15807     68.6         24.5         6.0
# 153 Texas "Dawson"       13542     68.5         21.9         9.5
# 154 Texas "Milam"        24344     68.5         21.3         9.8
# 155 Texas "Red River"    12567     68.5         17.4        13.8
# 156 Texas "Brazos"      205271     68.3         25.6         5.8
# 157 Texas "Starr"        62648     68.2         22.5         8.6
# 158 Texas "Houston"      22949     67.8         22.1         9.8
# 159 Texas "Reeves"       14179     67.8         28.3         3.9
# 160 Texas "Runnels"      10445     67.7         19.9        12.1
# 161 Texas "Willacy"      22002     66.9         23.9         9.1
# 162 Texas "Uvalde"       26952     66.8         23.8         9.4
# 163 Texas "Wilbarger"    13158     66.0         29.6         4.4
# 164 Texas "Val Verde"    48980     65.9         28.9         5.1
# 165 Texas "Lampasas"     20219     65.5         26.5         8.0
# 166 Texas "Madison"      13838     65.1         22.4        11.8
# 167 Texas "Limestone"    23454     61.3         28.6        10.1
# 168 Texas "Coryell"      76128     60.3         34.2         5.3
# 169 Texas "Walker"       69330     59.5         36.2         4.2

# %% [markdown]
# ### `05-Calculating the number of government employees`
# - Use `mutate()` to add a column called `public_workers` to the dataset, with the number of people employed in public (government) work.
#
# - Sort the new column in descending order.

# %%
counties_selected <- counties %>%
  select(state, county, population, public_work)

counties_selected %>%
  mutate(public_workers = public_work * population / 100) %>%
  # Sort in descending order of the public_workers column
  arrange(desc(public_workers))
# Out:
#      state      county              population public_work public_workers
# 1    California "Los Angeles"       10038388   11.5        1154414.6
# 2    Illinois   "Cook"               5236393   11.5         602185.2
# 3    California "San Diego"          3223096   14.8         477018.2
# 4    Arizona    "Maricopa"           4018143   11.7         470122.7
# 5    Texas      "Harris"             4356362   10.1         439992.6
# 6    New York   "Kings"              2595259   14.4         373717.3
# 7    California "San Bernardino"     2094769   16.7         349826.4
# 8    California "Riverside"          2298032   14.9         342406.8
# 9    California "Sacramento"         1465832   21.8         319551.4
# 10   California "Orange"             3116069   10.2         317839.0
# 11   New York   "Queens"             2301139   13.6         312954.9
# 12   New York   "Suffolk"            1501373   18.1         271748.5
# 13   Texas      "Bexar"              1825502   14.8         270174.3
# 14   Florida    "Miami-Dade"         2639042   10.2         269182.3
# 15   Washington "King"               2045756   12.4         253673.7
# 16   Maryland   "Prince George's"     892816   27.2         242846.0
# 17   Virginia   "Fairfax"            1128722   21.5         242675.2
# 18   Texas      "Dallas"             2485003    9.5         236075.3
# 19   New York   "Nassau"             1354612   16.4         222156.4
# 20   Maryland   "Montgomery"         1017859   21.7         220875.4
# 21   California "Alameda"            1584983   13.8         218727.7
# 22   Texas      "Tarrant"            1914526   11.4         218256.0
# 23   Nevada     "Clark"              2035572   10.7         217806.2
# 24   Hawaii     "Honolulu"            984178   22.1         217503.3
# 25   New York   "Bronx"              1428357   14.8         211396.8
# 26   Florida    "Broward"            1843152   11.3         208276.2
# 27   Pennsylvan ia   "Philadelphia"  1555072   13.0         202159.4
# 28   Arizona    "Pima"                998537   18.3         182732.3
# 29   Ohio       "Franklin"           1215761   14.8         179932.6
# 30   Texas      "Travis"             1121645   16.0         179463.2
# ⋮    ⋮          ⋮                   ⋮          ⋮           ⋮
# 3109 Nebraska   "Rock"              1401       14.4        201.744
# 3110 Montana    "Wheatland"         2115        9.5        200.925
# 3111 Texas      "Glasscock"         1180       17.0        200.600
# 3112 Texas      "McMullen"           778       25.6        199.168
# 3113 Mississipp i    "Issaquena"    1291       15.4        198.814
# 3114 Montana    "Carter"            1227       16.0        196.320
# 3115 Idaho      "Clark"              901       21.5        193.715
# 3116 Montana    "Golden Valley"      756       23.2        175.392
# 3117 North Dako ta   "Sheridan"     1337       13.0        173.810
# 3118 North Dako ta   "Billings"      969       17.6        170.544
# 3119 North Dako ta   "Steele"       1979        8.5        168.215
# 3120 Nebraska   "Hooker"             681       23.6        160.716
# 3121 Nebraska   "Banner"             820       19.1        156.620
# 3122 Nebraska   "Thomas"             675       22.3        150.525
# 3123 Nebraska   "Wheeler"            847       16.8        142.296
# 3124 Colorado   "Mineral"            733       18.8        137.804
# 3125 Nebraska   "Logan"              851       14.0        119.140
# 3126 Nebraska   "Keya Paha"          711       16.6        118.026
# 3127 South Dako ta   "Jones"         781       14.7        114.807
# 3128 Nebraska   "Loup"               548       19.5        106.860
# 3129 North Dako ta   "Slope"         673       15.5        104.315
# 3130 Montana    "Treasure"           812       12.4        100.688
# 3131 Montana    "Petroleum"          443       22.0         97.460
# 3132 Nebraska   "Blaine"             551       17.1         94.221
# 3133 Nebraska   "Grant"              769       12.2         93.818
# 3134 Nebraska   "Arthur"             448       17.1         76.608
# 3135 Colorado   "San Juan"           606       11.3         68.478
# 3136 Texas      "King"               267       21.1         56.337
# 3137 Hawaii     "Kalawao"             85       64.1         54.485
# 3138 Nebraska   "McPherson"          433        5.9         25.547

# %% [markdown]
# ### `06-Calculating the percentage of women in a county`
# - Select the columns `state`, `county`, `population`, `men`, and `women`.
# - Add a new variable called `proportion_women` with the fraction of the county's population made up of women.

# %%
counties_selected <- counties %>%
  # Select the columns state, county, population, men, and women
  select(state, county, population, men, women)

counties_selected
# Out:
#      state     county        population men    women
# 1    Alabama   "Autauga"      55221     26700  28500
# 2    Alabama   "Baldwin"     195121     95300  99800
# 3    Alabama   "Barbour"      26932     14500  12400
# 4    Alabama   "Bibb"         22604     12100  10500
# 5    Alabama   "Blount"       57710     28500  29200
# 6    Alabama   "Bullock"      10678      5660   5020
# 7    Alabama   "Butler"       20354      9500  10900
# 8    Alabama   "Calhoun"     116648     56300  60400
# 9    Alabama   "Chambers"     34079     16300  17800
# 10   Alabama   "Cherokee"     26008     13000  13000
# 11   Alabama   "Chilton"      43819     21600  22200
# 12   Alabama   "Choctaw"      13395      6380   7010
# 13   Alabama   "Clarke"       25070     11800  13200
# 14   Alabama   "Clay"         13537      6670   6870
# 15   Alabama   "Cleburne"     15002      7330   7670
# 16   Alabama   "Coffee"       50884     25200  25700
# 17   Alabama   "Colbert"      54444     26300  28100
# 18   Alabama   "Conecuh"      12865      6180   6690
# 19   Alabama   "Coosa"        11027      5580   5450
# 20   Alabama   "Covington"    37886     18300  19500
# 21   Alabama   "Crenshaw"     13938      6860   7080
# 22   Alabama   "Cullman"      80965     40100  40900
# 23   Alabama   "Dale"         49866     24700  25200
# 24   Alabama   "Dallas"       42154     19400  22700
# 25   Alabama   "DeKalb"       71068     35500  35600
# 26   Alabama   "Elmore"       80763     39400  41400
# 27   Alabama   "Escambia"     37935     19500  18400
# 28   Alabama   "Etowah"      103766     50200  53600
# 29   Alabama   "Fayette"      16896      8480   8420
# 30   Alabama   "Franklin"     31634     15300  16300
# ⋮    ⋮         ⋮             ⋮          ⋮      ⋮
# 3109 Wisconsin "Washburn"     15700       7800   7900
# 3110 Wisconsin "Washington"  132921      65900  67000
# 3111 Wisconsin "Waukesha"    393873     193000 200000
# 3112 Wisconsin "Waupaca"      52125      26400  25700
# 3113 Wisconsin "Waushara"     24321      12800  11500
# 3114 Wisconsin "Winnebago"   169004      85000  84000
# 3115 Wisconsin "Wood"         74012      36600  37400
# 3116 Wyoming   "Albany"       37565      19700  17900
# 3117 Wyoming   "Big Horn"     11895       6000   5890
# 3118 Wyoming   "Campbell"     48013      24900  23100
# 3119 Wyoming   "Carbon"       15739       8590   7150
# 3120 Wyoming   "Converse"     14101       7120   6980
# 3121 Wyoming   "Crook"         7229       3720   3510
# 3122 Wyoming   "Fremont"      40755      20400  20400
# 3123 Wyoming   "Goshen"       13544       7180   6360
# 3124 Wyoming   "Hot Springs"   4809       2390   2420
# 3125 Wyoming   "Johnson"       8600       4530   4080
# 3126 Wyoming   "Laramie"      95431      47900  47500
# 3127 Wyoming   "Lincoln"      18316       9360   8960
# 3128 Wyoming   "Natrona"      80011      40500  39500
# 3129 Wyoming   "Niobrara"      2516       1160   1350
# 3130 Wyoming   "Park"         28985      14200  14800
# 3131 Wyoming   "Platte"        8750       4500   4260
# 3132 Wyoming   "Sheridan"     29738      14700  15000
# 3133 Wyoming   "Sublette"     10117       5350   4760
# 3134 Wyoming   "Sweetwater"   44772      23400  21400
# 3135 Wyoming   "Teton"        22311      11500  10800
# 3136 Wyoming   "Uinta"        20930      10600  10300
# 3137 Wyoming   "Washakie"      8400       4140   4260
# 3138 Wyoming   "Weston"        7152       3700   3460

# %%
counties_selected <- counties %>%
  # Select the columns state, county, population, men, and women
  select(state, county, population, men, women)

counties_selected %>%
  # Calculate proportion_women as the fraction of the population made up of women
  mutate(proportion_women = women / population)
# Out:
#      state     county        population men    women  proportion_women
# 1    Alabama   "Autauga"      55221     26700  28500  0.5161080
# 2    Alabama   "Baldwin"     195121     95300  99800  0.5114775
# 3    Alabama   "Barbour"      26932     14500  12400  0.4604188
# 4    Alabama   "Bibb"         22604     12100  10500  0.4645196
# 5    Alabama   "Blount"       57710     28500  29200  0.5059782
# 6    Alabama   "Bullock"      10678      5660   5020  0.4701255
# 7    Alabama   "Butler"       20354      9500  10900  0.5355213
# 8    Alabama   "Calhoun"     116648     56300  60400  0.5177971
# 9    Alabama   "Chambers"     34079     16300  17800  0.5223158
# 10   Alabama   "Cherokee"     26008     13000  13000  0.4998462
# 11   Alabama   "Chilton"      43819     21600  22200  0.5066295
# 12   Alabama   "Choctaw"      13395      6380   7010  0.5233296
# 13   Alabama   "Clarke"       25070     11800  13200  0.5265257
# 14   Alabama   "Clay"         13537      6670   6870  0.5074980
# 15   Alabama   "Cleburne"     15002      7330   7670  0.5112652
# 16   Alabama   "Coffee"       50884     25200  25700  0.5050704
# 17   Alabama   "Colbert"      54444     26300  28100  0.5161267
# 18   Alabama   "Conecuh"      12865      6180   6690  0.5200155
# 19   Alabama   "Coosa"        11027      5580   5450  0.4942414
# 20   Alabama   "Covington"    37886     18300  19500  0.5147020
# 21   Alabama   "Crenshaw"     13938      6860   7080  0.5079638
# 22   Alabama   "Cullman"      80965     40100  40900  0.5051565
# 23   Alabama   "Dale"         49866     24700  25200  0.5053543
# 24   Alabama   "Dallas"       42154     19400  22700  0.5385017
# 25   Alabama   "DeKalb"       71068     35500  35600  0.5009287
# 26   Alabama   "Elmore"       80763     39400  41400  0.5126110
# 27   Alabama   "Escambia"     37935     19500  18400  0.4850402
# 28   Alabama   "Etowah"      103766     50200  53600  0.5165468
# 29   Alabama   "Fayette"      16896      8480   8420  0.4983428
# 30   Alabama   "Franklin"     31634     15300  16300  0.5152684
# ⋮    ⋮         ⋮             ⋮          ⋮      ⋮      ⋮
# 3109 Wisconsin "Washburn"     15700       7800   7900 0.5031847
# 3110 Wisconsin "Washington"  132921      65900  67000 0.5040588
# 3111 Wisconsin "Waukesha"    393873     193000 200000 0.5077779
# 3112 Wisconsin "Waupaca"      52125      26400  25700 0.4930456
# 3113 Wisconsin "Waushara"     24321      12800  11500 0.4728424
# 3114 Wisconsin "Winnebago"   169004      85000  84000 0.4970297
# 3115 Wisconsin "Wood"         74012      36600  37400 0.5053235
# 3116 Wyoming   "Albany"       37565      19700  17900 0.4765074
# 3117 Wyoming   "Big Horn"     11895       6000   5890 0.4951660
# 3118 Wyoming   "Campbell"     48013      24900  23100 0.4811197
# 3119 Wyoming   "Carbon"       15739       8590   7150 0.4542855
# 3120 Wyoming   "Converse"     14101       7120   6980 0.4950004
# 3121 Wyoming   "Crook"         7229       3720   3510 0.4855443
# 3122 Wyoming   "Fremont"      40755      20400  20400 0.5005521
# 3123 Wyoming   "Goshen"       13544       7180   6360 0.4695806
# 3124 Wyoming   "Hot Springs"   4809       2390   2420 0.5032231
# 3125 Wyoming   "Johnson"       8600       4530   4080 0.4744186
# 3126 Wyoming   "Laramie"      95431      47900  47500 0.4977418
# 3127 Wyoming   "Lincoln"      18316       9360   8960 0.4891898
# 3128 Wyoming   "Natrona"      80011      40500  39500 0.4936821
# 3129 Wyoming   "Niobrara"      2516       1160   1350 0.5365660
# 3130 Wyoming   "Park"         28985      14200  14800 0.5106089
# 3131 Wyoming   "Platte"        8750       4500   4260 0.4868571
# 3132 Wyoming   "Sheridan"     29738      14700  15000 0.5044051
# 3133 Wyoming   "Sublette"     10117       5350   4760 0.4704952
# 3134 Wyoming   "Sweetwater"   44772      23400  21400 0.4779773
# 3135 Wyoming   "Teton"        22311      11500  10800 0.4840662
# 3136 Wyoming   "Uinta"        20930      10600  10300 0.4921166
# 3137 Wyoming   "Washakie"      8400       4140   4260 0.5071429
# 3138 Wyoming   "Weston"        7152       3700   3460 0.4837808

# %% [markdown]
# ### `07-Select, mutate, filter, and arrange`
#
# - Select only the columns `state`, `county`, `population`, `men`, and `women`.
# - Add a variable `proportion_men` with the fraction of the county's population made up of men.
# - Filter for counties with a population of at least ten thousand (`10000`).
# - Arrange counties in descending order of their proportion of men.

# %%
counties %>%
  # Select the five columns 
  select(state, county, population, men, women) %>%
  # Add the proportion_men variable
  mutate(proportion_men = men / population) %>%
  # Filter for population of at least 10,000
  filter(population >= 10000) %>%
  # Arrange proportion of men in descending order 
  arrange(desc(proportion_men))
# Out:
#      state      county                  population men   women proportion_men
# 1    Virginia   "Sussex"                11864       8130  3730 0.6852664
# 2    California "Lassen"                32645      21800 10800 0.6677899
# 3    Georgia    "Chattahoochee"         11914       7940  3970 0.6664428
# 4    Louisiana  "West Feliciana"        15415      10200  5190 0.6616932
# 5    Florida    "Union"                 15191       9830  5360 0.6470937
# 6    Texas      "Jones"                 19978      12700  7330 0.6356993
# 7    Missouri   "DeKalb"                12782       8080  4700 0.6321389
# 8    Texas      "Madison"               13838       8650  5190 0.6250903
# 9    Virginia   "Greensville"           11760       7300  4460 0.6207483
# 10   Texas      "Anderson"              57915      35500 22400 0.6129673
# 11   Arkansas   "Lincoln"               14062       8600  5470 0.6115773
# 12   Texas      "Bee"                   32659      19700 12900 0.6032028
# 13   Florida    "Hamilton"              14395       8670  5720 0.6022925
# 14   Illinois   "Lawrence"              16665      10000  6670 0.6000600
# 15   Mississipp i    "Tallahatchie"     14959       8910  6050 0.5956281
# 16   Mississipp i    "Greene"           14129       8410  5720 0.5952297
# 17   Texas      "Karnes"                14879       8800  6080 0.5914376
# 18   Texas      "Frio"                  18168      10700  7440 0.5889476
# 19   Florida    "Gulf"                  15785       9240  6550 0.5853659
# 20   Florida    "Franklin"              11628       6800  4830 0.5847953
# 21   Texas      "Walker"                69330      40500 28800 0.5841627
# 22   Georgia    "Telfair"               16416       9500  6910 0.5787037
# 23   Louisiana  "Allen"                 25653      14800 10900 0.5769306
# 24   Colorado   "Fremont"               46809      27000 19800 0.5768122
# 25   Ohio       "Noble"                 14508       8360  6150 0.5762338
# 26   Georgia    "Tattnall"              25302      14500 10800 0.5730772
# 27   Louisiana  "Claiborne"             16639       9520  7120 0.5721498
# 28   Texas      "Pecos"                 15807       9000  6800 0.5693680
# 29   Missouri   "Pulaski"               53443      30400 23100 0.5688303
# 30   Texas      "Howard"                36105      20500 15600 0.5677884
# ⋮    ⋮          ⋮                       ⋮          ⋮     ⋮     ⋮
# 2408 Georgia    "Toombs"                27210      12700 14500 0.4667402
# 2409 Alabama    "Butler"                20354       9500 10900 0.4667387
# 2410 South Caro lina "Barnwell"         22098      10300 11800 0.4661055
# 2411 Virginia   "Bristol city"          17524       8160  9370 0.4656471
# 2412 Mississipp i    "Clay"             20279       9440 10800 0.4655062
# 2413 Alabama    "Marengo"               20306       9450 10900 0.4653797
# 2414 Georgia    "Dougherty"             93310      43400 49900 0.4651163
# 2415 North Caro lina "Edgecombe"        55280      25700 29600 0.4649059
# 2416 Virginia   "Colonial Heights city" 17515       8140  9370 0.4647445
# 2417 Georgia    "Evans"                 10814       5020  5790 0.4642131
# 2418 Arkansas   "Desha"                 12379       5740  6640 0.4636885
# 2419 Mississipp i    "Coahoma"          25254      11700 13600 0.4632929
# 2420 Alabama    "Perry"                 10038       4650  5390 0.4632397
# 2421 Georgia    "Early"                 10579       4900  5680 0.4631818
# 2422 Virginia   "Essex"                 11151       5160  5990 0.4627388
# 2423 Virginia   "Petersburg city"       32123      14800 17400 0.4607291
# 2424 Alabama    "Dallas"                42154      19400 22700 0.4602173
# 2425 North Caro lina "Washington"       12668       5830  6840 0.4602147
# 2426 South Caro lina "Marion"           32167      14800 17400 0.4600989
# 2427 Alabama    "Macon"                 20018       9170 10900 0.4580877
# 2428 Virginia   "Fluvanna"              26014      11900 14100 0.4574460
# 2429 Virginia   "Danville city"         42450      19400 23000 0.4570082
# 2430 West Virgi nia  "Summers"          13544       6180  7360 0.4562906
# 2431 Missouri   "Audrain"               25783      11700 14100 0.4537874
# 2432 Virginia   "Martinsville city"     13624       6160  7470 0.4521433
# 2433 Virginia   "Williamsburg city"     14754       6660  8090 0.4514030
# 2434 Missouri   "Livingston"            15042       6790  8260 0.4514027
# 2435 Virginia   "Staunton city"         24193      10900 13300 0.4505435
# 2436 Alabama    "Sumter"                13341       5900  7440 0.4422457
# 2437 Georgia    "Pulaski"               11590       4870  6720 0.4201898

# %% [markdown]
# ### `The End`
