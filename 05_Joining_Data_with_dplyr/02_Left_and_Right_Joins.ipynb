# %% [markdown]
# # Section 02: Left and Right Joins

# %%
library(dplyr)
library(tidyverse)
# Out:
# Attaching package: 'dplyr'
#
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union
#
#
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.6     ✔ purrr   0.3.4
# ✔ tibble  3.1.7     ✔ stringr 1.4.0
# ✔ tidyr   1.2.0     ✔ forcats 0.5.1
# ✔ readr   2.1.2
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
inventories <- read.csv("C:\\Users\\mosman\\Desktop\\Github\\Data_Scientist_with_R\\00_Datasets\\inventories.csv", 
                    header=TRUE)

inventory_parts <- read.csv("C:\\Users\\mosman\\Desktop\\Github\\Data_Scientist_with_R\\00_Datasets\\inventory_parts.csv", 
                    header=TRUE)

# %%
inventory_parts_joined <- inventories %>%
  inner_join(inventory_parts, by =c("id" = "inventory_id")) %>%
  select(-id, -version) %>%
  arrange(desc(quantity))

millennium_falcon <- inventory_parts_joined %>%
  filter(set_num == "7965-1")

star_destroyer <- inventory_parts_joined %>%
  filter(set_num == "75190-1")

# %% [markdown]
# ### `01-Left joining two sets by part and color`
#
# - Left join the `star_destroyer` and `millennium_falcon` tables on the `part_num` and `color_id` columns with the suffixes `_falcon` and `_star_destroyer`.

# %%
# Combine the star_destroyer and millennium_falcon tables
millennium_falcon %>%
  left_join(star_destroyer, by = c("part_num", "color_id"), 
            suffix = c("_falcon", "_star_destroyer"))
# Out:
#     set_num_falcon part_num    color_id quantity_falcon is_spare_falcon
# 1   7965-1         63868       71       62              f
# 2   7965-1         3023         0       60              f
# 3   7965-1         3021        72       46              f
# 4   7965-1         2780         0       37              f
# 5   7965-1         2780         0       37              f
# 6   7965-1         60478       72       36              f
# 7   7965-1         6636        71       34              f
# 8   7965-1         3009        71       28              f
# 9   7965-1         3665        71       22              f
# 10  7965-1         2412b       72       20              f
# 11  7965-1         3010        71       19              f
# 12  7965-1         3004        71       18              f
# 13  7965-1         3022        19       17              f
# 14  7965-1         3795        72       17              f
# 15  7965-1         3678b       71       16              f
# 16  7965-1         2456        71       14              f
# 17  7965-1         3020        72       14              f
# 18  7965-1         50950       71       14              f
# 19  7965-1         92099       72       14              f
# 20  7965-1         3023        19       13              f
# 21  7965-1         44728        0       13              f
# 22  7965-1         6141        19       13              f
# 23  7965-1         6249        72       13              f
# 24  7965-1         47397       71       12              f
# 25  7965-1         47398       71       12              f
# 26  7965-1         3895        71       11              f
# 27  7965-1         63864       71       10              f
# 28  7965-1         3002        71        9              f
# 29  7965-1         3069b       71        9              f
# 30  7965-1         3666        72        9              f
# ⋮   ⋮              ⋮           ⋮        ⋮               ⋮
# 218 7965-1         4032a          0     1               f
# 219 7965-1         41539         71     1               f
# 220 7965-1         41769         71     1               f
# 221 7965-1         41770         71     1               f
# 222 7965-1         4274           1     1               t
# 223 7965-1         4274           1     1               t
# 224 7965-1         4345b         15     1               f
# 225 7965-1         4346          15     1               f
# 226 7965-1         44375a        71     1               f
# 227 7965-1         4522           0     1               f
# 228 7965-1         4733          15     1               f
# 229 7965-1         47543         71     1               f
# 230 7965-1         47543pr0006   47     1               f
# 231 7965-1         51739         72     1               f
# 232 7965-1         59349         72     1               f
# 233 7965-1         60479         71     1               f
# 234 7965-1         6106          71     1               f
# 235 7965-1         6134           4     1               f
# 236 7965-1         6141          41     1               t
# 237 7965-1         6141          41     1               t
# 238 7965-1         6141          47     1               t
# 239 7965-1         61485          0     1               f
# 240 7965-1         61780         72     1               f
# 241 7965-1         78c19         41     1               f
# 242 7965-1         86208         71     1               f
# 243 7965-1         87081          0     1               f
# 244 7965-1         87544         71     1               f
# 245 7965-1         87609         15     1               f
# 246 7965-1         92593         15     1               f
# 247 7965-1         95690       9999     1               f
#     set_num_star_destroyer quantity_star_destroyer is_spare_star_destroyer
# 1   NA                     NA                      NA
# 2   NA                     NA                      NA
# 3   75190-1                 6                      f
# 4   75190-1                36                      f
# 5   75190-1                 1                      t
# 6   NA                     NA                      NA
# 7   75190-1                 2                      f
# 8   75190-1                 2                      f
# 9   NA                     NA                      NA
# 10  75190-1                11                      f
# 11  NA                     NA                      NA
# 12  NA                     NA                      NA
# 13  NA                     NA                      NA
# 14  75190-1                11                      f
# 15  NA                     NA                      NA
# 16  NA                     NA                      NA
# 17  75190-1                 1                      f
# 18  NA                     NA                      NA
# 19  NA                     NA                      NA
# 20  NA                     NA                      NA
# 21  NA                     NA                      NA
# 22  NA                     NA                      NA
# 23  NA                     NA                      NA
# 24  NA                     NA                      NA
# 25  NA                     NA                      NA
# 26  NA                     NA                      NA
# 27  75190-1                16                      f
# 28  NA                     NA                      NA
# 29  NA                     NA                      NA
# 30  NA                     NA                      NA
# ⋮   ⋮                      ⋮                       ⋮
# 218 NA                     NA                      NA
# 219 NA                     NA                      NA
# 220 NA                     NA                      NA
# 221 NA                     NA                      NA
# 222 75190-1                12                      f
# 223 75190-1                 1                      t
# 224 NA                     NA                      NA
# 225 NA                     NA                      NA
# 226 NA                     NA                      NA
# 227 NA                     NA                      NA
# 228 NA                     NA                      NA
# 229 NA                     NA                      NA
# 230 NA                     NA                      NA
# 231 NA                     NA                      NA
# 232 NA                     NA                      NA
# 233 75190-1                13                      f
# 234 NA                     NA                      NA
# 235 NA                     NA                      NA
# 236 75190-1                 3                      f
# 237 75190-1                 1                      t
# 238 NA                     NA                      NA
# 239 NA                     NA                      NA
# 240 NA                     NA                      NA
# 241 NA                     NA                      NA
# 242 NA                     NA                      NA
# 243 NA                     NA                      NA
# 244 NA                     NA                      NA
# 245 NA                     NA                      NA
# 246 NA                     NA                      NA
# 247 NA                     NA                      NA

# %% [markdown]
# ### `02-Left joining two sets by color`
# - Sum the `quantity` column by `color_id` in the Millennium Falcon dataset.
# - Now, sum the `quantity` column by `color_id` in the Star Destroyer dataset.
#
# - Left join the two datasets, `millennium_falcon_colors` and `star_destroyer_colors`, using the `color_id` column and the `_falcon` and `_star_destroyer` suffixes.

# %%
# Aggregate Millennium Falcon for the total quantity in each part
millennium_falcon_colors <- millennium_falcon %>%
  group_by(color_id) %>%
  summarize(total_quantity = sum(quantity))

# Aggregate Star Destroyer for the total quantity in each part
star_destroyer_colors <- star_destroyer %>%
  group_by(color_id) %>%
  summarize(total_quantity = sum(quantity))

# Left join the Millennium Falcon colors to the Star Destroyer colors
millennium_falcon_colors %>%
  left_join(star_destroyer_colors, by = "color_id",
            suffix = c("_falcon", "_star_destroyer") )
# Out:
#    color_id total_quantity_falcon total_quantity_star_destroyer
# 1     0     196                   327
# 2     1      15                    24
# 3     4      17                    56
# 4    14       3                     5
# 5    15      12                    13
# 6    19      91                    13
# 7    28       3                    16
# 8    33       5                    NA
# 9    36       1                    14
# 10   41       6                    16
# 11   47       5                    NA
# 12   70       6                     1
# 13   71     586                   533
# 14   72     282                   373
# 15   80       3                    NA
# 16  148       1                    NA
# 17  179       2                    NA
# 18  320      12                     2
# 19 9999       1                     1

# %% [markdown]
# ### `03-Finding an observation that doesn't have a match`
# - Use a `left_join` to join together `sets` and `inventory_version_1` using their common column.
# - `filter` for where the `version` column is `NA` using `is.na`.

# %%
sets <- read.csv("C:\\Users\\mosman\\Desktop\\Github\\Data_Scientist_with_R\\00_Datasets\\sets.csv", 
                    header=TRUE)

# %%
inventory_version_1 <- inventories %>%
  filter(version == 1)

# Join versions to sets
sets %>%
  left_join(inventory_version_1, by = "set_num") %>%
  # Filter for where version is na
  filter(is.na(version))
# Out:
#   set_num name                       year theme_id num_parts id version
# 1 10261-1 Roller Coaster             2018 673      4124      NA NA
# 2 10875-1 Cargo Train                2018 634       105      NA NA
# 3 76081-1 The Milano vs. The Abilisk 2017 704       462      NA NA

# %% [markdown]
# ### `04-Counting part colors`
# - Use the `count` verb to count each `part_cat_id` in the `parts` table.
# - Use a `right_join` to join `part_categories`. You'll need to use the `part_cat_id` from the count and the `id` column from `part_categories`.
#
# - filter for where the column `n` is `NA`.

# %%
part_categories <- read.csv("C:\\Users\\mosman\\Desktop\\Github\\Data_Scientist_with_R\\00_Datasets\\part_categories.csv", 
                    header=TRUE)

# %%
parts %>%
  count(part_cat_id) %>%
  right_join(part_categories, by = c("part_cat_id" = "id")) %>%
  # Filter for NA
  filter(is.na(n))
# Out:
#      part_cat_id n name

# %% [markdown]
# ### `05-Cleaning up your count`
# - Use `replace_na` to replace NAs in the `n` column with the value `0`.

# %%
library(tidyr)

# %%
parts %>%
  count(part_cat_id) %>%
  right_join(part_categories, by = c("part_cat_id" = "id")) %>%
  # Use replace_na to replace missing values in the n column
  replace_na(list(n = 0))
# Out:
#    part_cat_id n    name
# 1   1           238 Baseplates
# 2   3           531 Bricks Sloped
# 3   4          4298 Duplo, Quatro and Primo
# 4   5           169 Bricks Special
# 5   6           264 Bricks Wedged
# 6   7           180 Containers
# 7   8            27 Technic Bricks
# 8   9           360 Plates Special
# 9  11          1429 Bricks
# 10 12           109 Technic Connectors
# 11 13           465 Minifigs
# 12 14            95 Plates
# 13 15           377 Tiles Special
# 14 16           402 Windows and Doors
# 15 17          3481 Non-LEGO
# 16 18           240 Hinges, Arms and Turntables
# 17 19          2332 Tiles
# 18 20           402 Bricks Round and Cones
# 19 21           270 Plates Round Curved and Dishes
# 20 22            33 Pneumatics
# 21 23           312 Panels
# 22 24           104 Other
# 23 25           103 Technic Steering, Suspension and Engine
# 24 26           199 Technic Special
# 25 27          1550 Minifig Accessories
# 26 28          1378 Plants and Animals
# 27 29           326 Wheels and Tyres
# 28 30           190 Tubes and Hoses
# 29 31           121 String, Bands and Reels
# 30 32           122 Bars, Ladders and Fences
# ⋮  ⋮           ⋮    ⋮
# 37 39            38 Magnets and Holders
# 38 40            94 Technic Panels
# 39 41          1430 Bionicle, Hero Factory and Constraction
# 40 42           686 Belville, Scala and Fabuland
# 41 43            22 Znap
# 42 44            26 Mechanical
# 43 45           497 Power Functions, Mindstorms and Electric
# 44 46            27 Technic Axles
# 45 47           376 Windscreens and Fuselage
# 46 48           405 Clikits
# 47 49            72 Plates Angled
# 48 50           101 HO Scale
# 49 51            42 Technic Beams
# 50 52            83 Technic Gears
# 51 53            32 Technic Pins
# 52 54             7 Technic Bushes
# 53 55            30 Technic Beams Special
# 54 56            21 Tools
# 55 57          1093 Non-Buildable Figures (Duplo, Fabuland, etc)
# 56 58          3555 Stickers
# 57 59          3966 Minifig Heads
# 58 60          5697 Minifig Upper Body
# 59 61          2236 Minifig Lower Body
# 60 62           234 Minidoll Heads
# 61 63           449 Minidoll Upper Body
# 62 64           303 Minidoll Lower Body
# 63 65          1704 Minifig Headwear
# 64 66          1159 Modulex
# 65 67           746 Tiles Round and Curved
# 66 68            70 Projectiles / Launchers

# %% [markdown]
# ### `06-Joining themes to their children`
#
# - Inner join `themes` to their own children, resulting in the suffixes `"_parent"` and `"_child"`, respectively.
# - Filter this table to find the children of the `"Harry Potter"` theme

# %%
themes <- read.csv("C:\\Users\\mosman\\Desktop\\Github\\Data_Scientist_with_R\\00_Datasets\\themes.csv", 
                    header=TRUE)

# %%
themes %>% 
  # Inner join the themes table
  inner_join(themes, by = c("id" = "parent_id"), suffix = c("_parent", "_child")) %>%
  # Filter for the "Harry Potter" parent name 
  filter(name_parent == "Harry Potter")
# Out:
#   id  name_parent  parent_id id_child name_child
# 1 246 Harry Potter NA        667      Fantastic Beasts

# %% [markdown]
# ### `07-Joining themes to their grandchildren`
#
# - Use another inner join to combine themes again with itself.
#     - Be sure to use the suffixes `"_parent"` and `"_grandchild"` so the columns in the resulting table are clear.
#     - Update the `by` argument to specify the correct columns to join on. If you're unsure of what columns to join on, it might help to look at the result of the first join to get a feel for it.

# %%
# Join themes to itself again to find the grandchild relationships
themes %>% 
  inner_join(themes, by = c("id" = "parent_id"), suffix = c("_parent", "_child")) %>%
  inner_join(themes, by = c("id_child" = "parent_id"), suffix = c("_parent", "_grandchild"))
# Out:
#    id_parent name_parent           parent_id id_child name_child
# 1   22       Creator               NA         23      Basic Model
# 2   22       Creator               NA         23      Basic Model
# 3  147       Pirates               NA        148      Pirates I
# 4  147       Pirates               NA        148      Pirates I
# 5  147       Pirates               NA        148      Pirates I
# 6  206       Seasonal              NA        207      Advent
# 7  206       Seasonal              NA        207      Advent
# 8  206       Seasonal              NA        207      Advent
# 9  206       Seasonal              NA        207      Advent
# 10 206       Seasonal              NA        207      Advent
# 11 206       Seasonal              NA        207      Advent
# 12 206       Seasonal              NA        207      Advent
# 13 206       Seasonal              NA        207      Advent
# 14 206       Seasonal              NA        207      Advent
# 15 206       Seasonal              NA        207      Advent
# 16 206       Seasonal              NA        227      Christmas
# 17 504       Duplo                 NA        632      Town
# 18 504       Duplo                 NA        632      Town
# 19 507       Educational and Dacta NA        518      Mindstorms
# 20 507       Educational and Dacta NA        518      Mindstorms
# 21 507       Educational and Dacta NA        518      Mindstorms
# 22 507       Educational and Dacta NA        524      Service Packs
# 23 507       Educational and Dacta NA        529      Technic
# 24 507       Educational and Dacta NA        529      Technic
# 25 507       Educational and Dacta NA        529      Technic
# 26 695       Super Heroes DC       NA        697      Batman
# 27 695       Super Heroes DC       NA        697      Batman
#    id_grandchild name
# 1   34           Building
# 2   35           Cargo
# 3  149           Imperial Armada
# 4  151           Imperial Soldiers
# 5  152           Islanders
# 6  208           City
# 7  209           Star Wars
# 8  210           Belville
# 9  211           Castle
# 10 212           Classic Basic
# 11 213           Clikits
# 12 214           Creator
# 13 215           Pirates
# 14 216           Friends
# 15 710           Harry Potter
# 16 228           Creator
# 17 636           My Town
# 18 650           Legoville
# 19 519           NXT
# 20 520           RCX
# 21 521           WeDo
# 22 525           Technic
# 23 530           Control Lab
# 24 531           eLAB
# 25 532           Supplemental
# 26 698           UCS
# 27 708           The LEGO Batman Movie

# %% [markdown]
# ### `08-Left joining a table to itself`
# - Left join the themes table to its own children, with the suffixes `_parent` and `_child` respectively.
# - Filter the result of the join to find themes that have no children.

# %%
themes %>% 
  # Left join the themes table to its own children
  left_join(themes, by = c("id" = "parent_id"), 
            suffix = c("_parent", "_child")) %>%
  # Filter for themes that have no child themes
  filter(is.na(name_child))
# Out:
#     id  name_parent                                parent_id id_child
# 1    3  Competition                                 1        NA
# 2    4  Expert Builder                              1        NA
# 3   16  RoboRiders                                  1        NA
# 4   17  Speed Slammers                              1        NA
# 5   18  Star Wars                                   1        NA
# 6   19  Supplemental                                1        NA
# 7   20  Throwbot Slizer                             1        NA
# 8   21  Universal Building Set                      1        NA
# 9   34  Building                                   23        NA
# 10  35  Cargo                                      23        NA
# 11  51  Arctic                                     50        NA
# 12  53  Airport                                    52        NA
# 13  54  Cargo                                      52        NA
# 14  55  Coast Guard                                52        NA
# 15  56  Construction                               52        NA
# 16  57  Farm                                       52        NA
# 17  58  Fire                                       52        NA
# 18  59  Harbor                                     52        NA
# 19  60  Hospital                                   52        NA
# 20  61  Police                                     52        NA
# 21  63  Traffic                                    52        NA
# 22  64  Off-Road                                   52        NA
# 23  65  Arctic                                     52        NA
# 24  66  Trains                                     52        NA
# 25  67  Classic Town                               50        NA
# 26  86  Divers                                     50        NA
# 27  87  Extreme Team                               50        NA
# 28  88  Launch Command                             50        NA
# 29  89  Outback                                    50        NA
# 30  90  Paradisa                                   50        NA
# ⋮   ⋮   ⋮                                          ⋮         ⋮
# 363 689 Minions                                     NA       NA
# 364 690 Super Mario                                 NA       NA
# 365 691 Harry Potter and Fantastic Beasts Series 2 535       NA
# 366 692 Series 20 Minifigures                      535       NA
# 367 693 Monkie Kid                                  NA       NA
# 368 694 Brick Sketches                              NA       NA
# 369 698 UCS                                        697       NA
# 370 699 Constraction                               695       NA
# 371 700 Justice League                             695       NA
# 372 701 Superman                                   695       NA
# 373 702 Avengers                                   696       NA
# 374 703 Constraction                               696       NA
# 375 704 Guardians of the Galaxy                    696       NA
# 376 705 Iron Man                                   696       NA
# 377 706 Spider-Man                                 696       NA
# 378 707 X-Men                                      696       NA
# 379 708 The LEGO Batman Movie                      697       NA
# 380 709 LEGO Art                                    NA       NA
# 381 710 Harry Potter                               207       NA
# 382 711 The LEGO Batman Movie Series 2             535       NA
# 383 712 Series 21 Minifigures                      535       NA
# 384 713 VIDIYO                                      NA       NA
# 385 714 Looney Tunes                               535       NA
# 386 715 Marvel                                     535       NA
# 387 716 Modulex                                     NA       NA
# 388 717 Speed Racer                                 NA       NA
# 389 718 Series 22 Minifigures                      535       NA
# 390 719 BrickLink Designer Program                  NA       NA
# 391 720 The Muppets                                535       NA
# 392 721 Icons                                       NA       NA
#     name_child
# 1   NA
# 2   NA
# 3   NA
# 4   NA
# 5   NA
# 6   NA
# 7   NA
# 8   NA
# 9   NA
# 10  NA
# 11  NA
# 12  NA
# 13  NA
# 14  NA
# 15  NA
# 16  NA
# 17  NA
# 18  NA
# 19  NA
# 20  NA
# 21  NA
# 22  NA
# 23  NA
# 24  NA
# 25  NA
# 26  NA
# 27  NA
# 28  NA
# 29  NA
# 30  NA
# ⋮   ⋮
# 363 NA
# 364 NA
# 365 NA
# 366 NA
# 367 NA
# 368 NA
# 369 NA
# 370 NA
# 371 NA
# 372 NA
# 373 NA
# 374 NA
# 375 NA
# 376 NA
# 377 NA
# 378 NA
# 379 NA
# 380 NA
# 381 NA
# 382 NA
# 383 NA
# 384 NA
# 385 NA
# 386 NA
# 387 NA
# 388 NA
# 389 NA
# 390 NA
# 391 NA
# 392 NA

# %% [markdown]
# ### `The End`
