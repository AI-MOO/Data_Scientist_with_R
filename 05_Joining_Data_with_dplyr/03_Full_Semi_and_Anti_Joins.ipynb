# %% [markdown]
# # Section 03: Full, Semi, and Anti Joins

# %% [markdown]
# ### `01-Differences between Batman and Star Wars`
# - In order to join in the themes, you'll first need to combine the `inventory_parts_joined` and `sets` tables.
# - Then, combine the first join with the `themes` table, using the suffix argument to clarify which table each `name` came from (`"_set"` or `"_theme"`).

# %%
library(dplyr)
library(tidyverse)
# Out:
# Attaching package: 'dplyr'
#
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union
#
#
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.6     ✔ purrr   0.3.4
# ✔ tibble  3.1.7     ✔ stringr 1.4.0
# ✔ tidyr   1.2.0     ✔ forcats 0.5.1
# ✔ readr   2.1.2
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
inventories <- read.csv("..\\00_Datasets\\inventories.csv", header=TRUE)
inventory_parts <- read.csv("..\\00_Datasets\\inventory_parts.csv", header=TRUE)
sets <- read.csv("..\\00_Datasets\\sets.csv", header=TRUE)
themes <- read.csv("..\\00_Datasets\\themes.csv", header=TRUE)

# %%
inventory_parts_joined <- inventories %>%
  inner_join(inventory_parts, by = c("id" = "inventory_id")) %>%
  arrange(desc(quantity)) %>%
  select(-id, -version)

# %%
str(sets)
# Out:
# 'data.frame':	19452 obs. of  5 variables:
#  $ set_num  : chr  "001-1" "0011-2" "0011-3" "0012-1" ...
#  $ name     : chr  "Gears" "Town Mini-Figures" "Castle 2 for 1 Bonus Offer" "Space Mini-Figures" ...
#  $ year     : int  1965 1979 1987 1979 1979 1979 1979 1979 1965 2013 ...
#  $ theme_id : int  1 67 199 143 143 143 143 186 1 497 ...
#  $ num_parts: int  43 12 0 12 12 12 18 15 3 4 ...

# %%
str(inventory_parts_joined)
# Out:
# 'data.frame':	1038581 obs. of  5 variables:
#  $ set_num : chr  "31203-1" "31203-1" "31203-1" "k34432-1" ...
#  $ part_num: chr  "6141" "98138" "98138" "3024" ...
#  $ color_id: int  15 3 322 15 15 27 0 71 72 14 ...
#  $ quantity: int  3064 1879 1607 1440 1170 1060 900 900 900 900 ...
#  $ is_spare: chr  "f" "f" "f" "f" ...

# %%
# Start with inventory_parts_joined table
inventory_parts_joined %>%
  # Combine with the sets table 
  inner_join(sets, by = "set_num") %>%
  # Combine with the themes table 
  inner_join(themes, by = c("theme_id" = "id"), suffix = c("_set", "_theme"))
# Out:
#        set_num   part_num    color_id quantity is_spare
# 1      31203-1   6141         15      3064     f
# 2      31203-1   98138         3      1879     f
# 3      31203-1   98138       322      1607     f
# 4      k34432-1  3024         15      1440     f
# 5      k34433-1  3024         15      1170     f
# 6      31203-1   98138        27      1060     f
# 7      40179-1   3024          0       900     f
# 8      40179-1   3024         71       900     f
# 9      40179-1   3024         72       900     f
# 10     40179-1   3024         14       900     f
# 11     40179-1   3024         15       900     f
# 12     31200-1   6141          0       877     f
# 13     6250093-1 3024        320       849     f
# 14     31202-1   98138        15       835     f
# 15     K34434-1  3024         15       810     f
# 16     6268522-1 3024          0       789     f
# 17     21010-1   3023        320       771     f
# 18     6268521-1 3024          0       761     f
# 19     31203-1   98138        19       725     f
# 20     42055-1   2780          0       724     f
# 21     k34431-1  3024          0       720     f
# 22     42131-1   61332         0       707     f
# 23     42131-1   61332         0       707     f
# 24     31198-1   98138         0       698     f
# 28     Disney's Mickey Mouse         2021 709       2658     LEGO Art
# 29     Art Project - Create Together 2021 709       4138     LEGO Art
# 30     Lego Mosaic Dino              2003 277       2847     Mosaic
# ⋮      ⋮                             ⋮    ⋮        ⋮         ⋮
# 981495 Boulder Blaster               2021 435      449       Ninjago
# 981496 Boulder Blaster               2021 435      449       Ninjago
# 981497 Boulder Blaster               2021 435      449       Ninjago
# 981498 Boulder Blaster               2021 435      449       Ninjago
# 981499 Boulder Blaster               2021 435      449       Ninjago
# 981500 Boulder Blaster               2021 435      449       Ninjago
# 981501 Boulder Blaster               2021 435      449       Ninjago
# 981502 Boulder Blaster               2021 435      449       Ninjago
# 981503 Boulder Blaster               2021 435      449       Ninjago
# 981504 Boulder Blaster               2021 435      449       Ninjago
# 981505 Boulder Blaster               2021 435      449       Ninjago
# 981506 Boulder Blaster               2021 435      449       Ninjago
# 981507 Boulder Blaster               2021 435      449       Ninjago
# 981508 Boulder Blaster               2021 435      449       Ninjago
# 981509 Boulder Blaster               2021 435      449       Ninjago
# 981510 Boulder Blaster               2021 435      449       Ninjago
# 981511 Raptor and Nest               2022 602       23       Jurassic World
# 981512 Raptor and Nest               2022 602       23       Jurassic World
# 981513 Raptor and Nest               2022 602       23       Jurassic World
# 981514 Raptor and Nest               2022 602       23       Jurassic World
# 981515 Raptor and Nest               2022 602       23       Jurassic World
# 981516 Raptor and Nest               2022 602       23       Jurassic World
# 981517 Raptor and Nest               2022 602       23       Jurassic World
# 981518 Raptor and Nest               2022 602       23       Jurassic World
# 981519 Raptor and Nest               2022 602       23       Jurassic World
# 981520 Triceratops Baby              2022 504        1       Duplo
# 981521 Lloyd vs. Overlord            2022 435       12       Ninjago
# 981522 Lloyd vs. Overlord            2022 435       12       Ninjago
# 981523 Lloyd vs. Overlord            2022 435       12       Ninjago
# 981524 Lloyd vs. Overlord            2022 435       12       Ninjago
#        parent_id
# 1       NA
# 2       NA
# 3       NA
# 4      276
# 5      276
# 6       NA
# 7      276
# 8      276
# 9      276
# 10     276
# 11     276
# 12      NA
# 13     696
# 14      NA
# 15     276
# 16      NA
# 17      NA
# 18      NA
# 19      NA
# 20      NA
# 21     276
# 22      NA
# 23      NA
# 24      NA
# 25      NA
# 26      NA
# 27      NA
# 28      NA
# 29      NA
# 30     276
# ⋮      ⋮
# 981495 NA
# 981496 NA
# 981497 NA
# 981498 NA
# 981499 NA
# 981500 NA
# 981501 NA
# 981502 NA
# 981503 NA
# 981504 NA
# 981505 NA
# 981506 NA
# 981507 NA
# 981508 NA
# 981509 NA
# 981510 NA
# 981511 NA
# 981512 NA
# 981513 NA
# 981514 NA
# 981515 NA
# 981516 NA
# 981517 NA
# 981518 NA
# 981519 NA
# 981520 NA
# 981521 NA
# 981522 NA
# 981523 NA
# 981524 NA

# %% [markdown]
# ### `02-Aggregating each theme`
# - Count the part number and color id for the parts in Batman and Star Wars, weighted by quantity.

# %%
inventory_sets_themes <- inventory_parts_joined %>%
  inner_join(sets, by = "set_num") %>%
  inner_join(themes, by = c("theme_id" = "id"), suffix = c("_set", "_theme"))

batman <- inventory_sets_themes %>%
  filter(name_theme == "Batman")

star_wars <- inventory_sets_themes %>%
  filter(name_theme == "Star Wars")

# %%
head(inventory_sets_themes, 3)
# Out:
#   set_num part_num color_id quantity is_spare name_set  year theme_id num_parts
# 1 31203-1 6141      15      3064     f        World Map 2021 709      11695
# 2 31203-1 98138      3      1879     f        World Map 2021 709      11695
# 3 31203-1 98138    322      1607     f        World Map 2021 709      11695
#   name_theme parent_id
# 1 LEGO Art   NA
# 2 LEGO Art   NA
# 3 LEGO Art   NA

# %%
# Count the part number and color id, weight by quantity
batman %>%
  count(part_num, color_id, wt = quantity)

star_wars %>%
  count(part_num, color_id, wt = quantity)
# Out:
#      part_num     color_id n
# 1    10100596     9999      1
# 2    10172         179      1
# 3    10172         297      1
# 4    10187         179      3
# 5    10187         297      3
# 6    10190           0      6
# 7    10201           4      3
# 8    10201          14      5
# 9    10201          15      6
# 10   10201          71     25
# 11   10202          71      3
# 12   10247           0      4
# 13   10247           4      6
# 14   10247          14     11
# 15   10247          71      8
# 16   10247          72      9
# 17   10288         308      1
# 18   10314           0      2
# 19   10830pat0001    0      1
# 20   10884           2      3
# 21   10884          27      2
# 22   10928          72      5
# 23   11055           0      2
# 24   11055           4      1
# 25   11089           0      2
# 26   11090           0      6
# 27   11090          14      3
# 28   11090          70      2
# 29   11090          72     11
# 30   11090         179      5
# ⋮    ⋮            ⋮        ⋮
# 3315 98834         85        4
# 3316 98834        379        3
# 3317 99021         72        7
# 3318 99206          0       23
# 3319 99206          4        5
# 3320 99206         15        3
# 3321 99206         19        1
# 3322 99206         70        3
# 3323 99206         71       28
# 3324 99207          0       23
# 3325 99207          4        6
# 3326 99207         70        3
# 3327 99207         71      102
# 3328 99207         72        4
# 3329 99563          0       18
# 3330 99563         72        2
# 3331 99563        148        3
# 3332 99563        179        5
# 3333 99780          0       29
# 3334 99780          2        1
# 3335 99780          4        6
# 3336 99780         14        2
# 3337 99780         71       45
# 3338 99780         72       41
# 3339 99781          0       25
# 3340 99781         14        4
# 3341 99781         15        2
# 3342 99781         71       26
# 3343 99781         72        8
# 3344 99784        272        2
#      part_num       color_id n
# 1    01571          9999       1
# 2    01709          9999       1
# 3    01832          9999       1
# 4    10001722       9999       1
# 5    10001831       9999       1
# 6    10050           148       1
# 7    10050          1063       4
# 8    10100101       9999       1
# 9    10164pr0001      15       1
# 10   10169             4       1
# 11   10169            84       1
# 12   10197             0      19
# 13   10197            72      39
# 14   10201             0      50
# 15   10201             1       2
# 16   10201             4       7
# 17   10201            14       2
# 18   10201            15       2
# 19   10201            70       8
# 20   10201            71      70
# 21   10202            71       1
# 22   10202            72       2
# 23   10247             0     100
# 24   10247             4      20
# 25   10247            14      12
# 26   10247            15      16
# 27   10247            71      97
# 28   10247            72      85
# 29   10288             0       1
# 30   10288           308       4
# ⋮    ⋮              ⋮        ⋮
# 8419 cardupn0060    9999      2
# 8420 cardupn0061    9999      2
# 8421 cardupn0062    9999      1
# 8422 cardupn0063    9999      1
# 8423 cardupn0064    9999      1
# 8424 cardupn0065    9999      1
# 8425 cardupn0066    9999      1
# 8426 cardupn0067    9999      1
# 8427 cardupn0068    9999      1
# 8428 cardupn0069    9999      1
# 8429 cardupn0070    9999      2
# 8430 case12            0      1
# 8431 flex08c05l        7      2
# 8432 flex08c10l        7      1
# 8433 flex08c157.5      6      2
# 8434 rotbcd         9999      1
# 8435 satchel4       9999      1
# 8436 stickerupn0009 9999      1
# 8437 u-2694         9999      1
# 8438 upn0144c09        6      2
# 8439 upn0144c12        6      2
# 8440 upn0214           8      1
# 8441 upn0228           0      4
# 8442 upn0228          15      2
# 8443 upn0372           0     26
# 8444 upn0372a          0      3
# 8445 upn0373           0     24
# 8446 upn0375           0     14
# 8447 upn0445        9999      1
# 8448 upn0446        9999      1

# %% [markdown]
# ### `03-Full joining Batman and Star Wars LEGO parts`
# - Combine the `star_wars_parts` table with the `batman_parts` table; use the suffix argument to include the `"_batman"` and `"_star_wars"` suffixes.
# - Replace all the NA values in the `n_batman` and `n_star_wars` columns with 0s.

# %%
batman_parts <- batman %>%
  count(part_num, color_id, wt = quantity)

star_wars_parts <- star_wars %>%
  count(part_num, color_id, wt = quantity)

# %%
head(batman_parts)
head(star_wars_parts)
# Out:
#   part_num color_id n
# 1 10100596 9999     1
# 2 10172     179     1
# 3 10172     297     1
# 4 10187     179     3
# 5 10187     297     3
# 6 10190       0     6
#   part_num color_id n
# 1 01571    9999     1
# 2 01709    9999     1
# 3 01832    9999     1
# 4 10001722 9999     1
# 5 10001831 9999     1
# 6 10050     148     1

# %%
batman_parts %>%
  # Combine the star_wars_parts table 
  full_join(star_wars_parts, by = c("part_num", "color_id"), suffix = c("_batman", "_star_wars")) %>%
  # Replace NAs with 0s in the n_batman and n_star_wars columns 
  replace_na(list(n_batman = 0,
                  n_star_wars = 0))
# Out:
#      part_num       color_id n_batman n_star_wars
# 1    10100596       9999      1         0
# 2    10172           179      1         0
# 3    10172           297      1         0
# 4    10187           179      3         0
# 5    10187           297      3         0
# 6    10190             0      6         0
# 7    10201             4      3         7
# 8    10201            14      5         2
# 9    10201            15      6         2
# 10   10201            71     25        70
# 11   10202            71      3         1
# 12   10247             0      4       100
# 13   10247             4      6        20
# 14   10247            14     11        12
# 15   10247            71      8        97
# 16   10247            72      9        85
# 17   10288           308      1         4
# 18   10314             0      2         2
# 19   10830pat0001      0      1         0
# 20   10884             2      3         0
# 21   10884            27      2         0
# 22   10928            72      5        39
# 23   11055             0      2         1
# 24   11055             4      1         2
# 25   11089             0      2         0
# 26   11090             0      6        26
# 27   11090            14      3         0
# 28   11090            70      2         0
# 29   11090            72     11        97
# 30   11090           179      5         0
# ⋮    ⋮              ⋮        ⋮        ⋮
# 9308 cardupn0060    9999     0         2
# 9309 cardupn0061    9999     0         2
# 9310 cardupn0062    9999     0         1
# 9311 cardupn0063    9999     0         1
# 9312 cardupn0064    9999     0         1
# 9313 cardupn0065    9999     0         1
# 9314 cardupn0066    9999     0         1
# 9315 cardupn0067    9999     0         1
# 9316 cardupn0068    9999     0         1
# 9317 cardupn0069    9999     0         1
# 9318 cardupn0070    9999     0         2
# 9319 case12            0     0         1
# 9320 flex08c05l        7     0         2
# 9321 flex08c10l        7     0         1
# 9322 flex08c157.5      6     0         2
# 9323 rotbcd         9999     0         1
# 9324 satchel4       9999     0         1
# 9325 stickerupn0009 9999     0         1
# 9326 u-2694         9999     0         1
# 9327 upn0144c09        6     0         2
# 9328 upn0144c12        6     0         2
# 9329 upn0214           8     0         1
# 9330 upn0228           0     0         4
# 9331 upn0228          15     0         2
# 9332 upn0372           0     0        26
# 9333 upn0372a          0     0         3
# 9334 upn0373           0     0        24
# 9335 upn0375           0     0        14
# 9336 upn0445        9999     0         1
# 9337 upn0446        9999     0         1

# %% [markdown]
# ### `04-Comparing Batman and Star Wars LEGO parts`
# - Sort the number of star wars pieces in the `parts_joined` table in descending order.
# - Inner join the `colors` table to the `parts_joined` table.
# - Combine the `parts` table to the previous join using an inner join; add `"_color"` and `"_part"` suffixes to specify whether or not the information came from the `colors` table or the `parts` table.

# %%
colors <- read.csv("..\\00_Datasets\\colors.csv", header=TRUE)
parts <- read.csv("..\\00_Datasets\\parts.csv", header=TRUE)

# %%
parts_joined <- batman_parts %>%
  full_join(star_wars_parts, by = c("part_num", "color_id"), suffix = c("_batman", "_star_wars")) %>%
  replace_na(list(n_batman = 0, n_star_wars = 0))

head(parts_joined, 3)
# Out:
#   part_num color_id n_batman n_star_wars
# 1 10100596 9999     1        0
# 2 10172     179     1        0
# 3 10172     297     1        0

# %%
parts_joined %>%
  # Sort the number of star wars pieces in descending order 
  arrange(desc(n_star_wars)) %>%
  # Join the colors table to the parts_joined table
  inner_join(colors, by = c("color_id" = "id")) %>%
  # Join the parts table to the previous join 
  inner_join(parts, by = "part_num", suffix = c("_color", "_part"))
# Out:
#      part_num    color_id n_batman n_star_wars name              rgb
# 1    2780         0       377      5188        Black             05131D
# 2    4274         1       166      2041        Blue              0055BF
# 3    3023        71       100      1733        Light Bluish Gray A0A5A9
# 4    3023        72       159      1580        Dark Bluish Gray  6C6E68
# 5    43093        1        95      1362        Blue              0055BF
# 6    3023         0       214      1342        Black             05131D
# 7    6141        36        86      1195        Trans-Red         C91A09
# 8    6141        72        91      1151        Dark Bluish Gray  6C6E68
# 9    2412b       72        70      1149        Dark Bluish Gray  6C6E68
# 10   6558         1        33      1131        Blue              0055BF
# 11   4274        71        43       993        Light Bluish Gray A0A5A9
# 12   3710        72        84       960        Dark Bluish Gray  6C6E68
# 13   3021        71        33       934        Light Bluish Gray A0A5A9
# 14   3710         0        72       921        Black             05131D
# 15   3020        72        84       881        Dark Bluish Gray  6C6E68
# 16   3710        71        68       870        Light Bluish Gray A0A5A9
# 17   3023        19        39       856        Tan               E4CD9E
# 18   6141         0        45       848        Black             05131D
# ### `05-Something within one set but not another`

# %%
batmobile <- inventory_parts_joined %>%
  filter(set_num == "7784-1") %>%
  select(-set_num)

batwing <- inventory_parts_joined %>%
  filter(set_num == "70916-1") %>%
  select(-set_num)

# %% [markdown]
# - Filter the `batwing` set for parts that are also in the `batmobile`, whether or not they have the same color.
# - Filter the `batwing` set for parts that aren't also in the `batmobile`, whether or not they have the same color.

# %%
# Filter the batwing set for parts that are also in the batmobile set
batwing %>%
  semi_join(batmobile, by = "part_num")

# Filter the batwing set for parts that aren't in the batmobile set
batwing %>%
  anti_join(batmobile, by = "part_num")
# Out:
#     part_num color_id quantity is_spare
# 1   3023       0      22       f
# 2   3024       0      22       f
# 3   3623       0      20       f
# 4   2780       0      17       f
# 5   3666       0      16       f
# 6   3710       0      14       f
# 7   6141       4      12       f
# 8   2412b     71      10       f
# 9   6141      72      10       f
# 10  6558       1       9       f
# 11  3021      72       8       f
# 12  3070b     72       8       f
# 13  3665       0       8       f
# 14  3020      72       7       f
# 15  3020       0       7       f
# 16  3666      71       7       f
# 17  4274      71       7       f
# 18  6141     182       7       f
# 19  2412b     72       6       f
# 20  3004       1       6       f
# 21  3023      70       6       f
# 22  3024       4       6       f
# 23  3623      14       6       f
# 24  4274       1       6       f
# 25  43093      1       6       f
# 26  44302a    72       6       f
# 27  44728     72       6       f
# 28  6541       4       6       f
# 29  2780       0       5       t
# 30  3069b      4       5       f
# ⋮   ⋮        ⋮        ⋮        ⋮
# 113 3070b    72       1        t
# 114 32123b   71       1        t
# 115 3298     72       1        f
# 116 3705      4       1        f
# 117 3707      4       1        f
# 118 3795     15       1        f
# 119 3795      4       1        f
# 120 3832      0       1        f
# 121 41747     0       1        f
# 122 41748     0       1        f
# 123 4286      0       1        f
# 124 4286      4       1        f
# 125 43722     0       1        f
# 126 43722    72       1        f
# 127 43723    72       1        f
# 128 43723     0       1        f
# 129 44294    71       1        f
# 130 47458     0       1        f
# 131 48336    71       1        f
# 132 50304     0       1        f
# 133 50304    72       1        f
# 134 50305    72       1        f
# 135 50305     0       1        f
# 136 54200    46       1        t
# 137 54200     0       1        f
# 138 54200     4       1        t
# 139 54200     4       1        f
# 140 54200     0       1        t
# 141 6141     72       1        t
# 142 6141      4       1        t
#     part_num color_id quantity is_spare
# 1   11477     0       18       f
# 2   99207    71       18       f
# 3   22385     0       14       f
# 4   99563     0       13       f
# 5   10247    72       12       f
# 6   2877     72       12       f
# 7   61409    72       12       f
# 8   11153     0       10       f
# 9   98138    46       10       f
# 10  2419     72        9       f
# 11  85984    72        9       f
# 12  15573    19        8       f
# 13  32054     4        8       f
# 14  4865b     0        8       f
# 15  60477     0        8       f
# 16  6106      0        8       f
# 17  6231      0        8       f
# 18  63864    72        8       f
# 19  98138    36        8       f
# 20  24201    71        6       f
# 21  2431      0        6       f
# 22  3005      0        6       f
# 23  3005     71        6       f
# 24  44301b   71        6       f
# 25  6179      0        6       f
# 26  15068     0        5       f
# 27  60219     0        5       f
# 28  85984     0        5       f
# 29  99781    71        5       f
# 30  11477    72        4       f
# ⋮   ⋮        ⋮        ⋮        ⋮
# 152 3709      15      1        f
# 153 3738      71      1        f
# 154 4032a     14      1        f
# 155 41769      0      1        f
# 156 41770      0      1        f
# 157 41854      0      1        f
# 158 42060      0      1        f
# 159 42061      0      1        f
# 160 43857     71      1        f
# 161 4624      71      1        t
# 162 47720      0      1        f
# 163 50955      0      1        f
# 164 50956      0      1        f
# 165 60594     72      1        f
# 166 63965     15      1        f
# 167 6585       0      1        f
# 168 85984     70      1        f
# 169 87079     70      1        f
# 170 87083     72      1        f
# 171 88930      0      1        f
# 172 92593     71      1        f
# 173 92692     15      1        f
# 174 96874     25      1        f
# 175 98138     34      1        t
# 176 98285     71      1        f
# 177 98286     71      1        f
# 178 98375    179      1        t
# 179 98375    179      1        f
# 180 98721      0      1        f
# 181 98721      0      1        t

# %% [markdown]
# ### `06-What colors are included in at least one set?`
# - Use the `inventory_parts` table to find the colors that are included in at least one set.

# %%
# Use inventory_parts to find colors included in at least one set
colors %>%
  semi_join(inventory_parts, by = c("id" = "color_id"))
# Out:
#     id   name                 rgb    is_trans
# 1   -1   [Unknown]            0033B2 f
# 2    0   Black                05131D f
# 3    1   Blue                 0055BF f
# 4    2   Green                237841 f
# 5    3   Dark Turquoise       008F9B f
# 6    4   Red                  C91A09 f
# 7    5   Dark Pink            C870A0 f
# 8    6   Brown                583927 f
# 9    7   Light Gray           9BA19D f
# 10   8   Dark Gray            6D6E5C f
# 11   9   Light Blue           B4D2E3 f
# 12  10   Bright Green         4B9F4A f
# 13  11   Light Turquoise      55A5AF f
# 14  12   Salmon               F2705E f
# 15  13   Pink                 FC97AC f
# 16  14   Yellow               F2CD37 f
# 17  15   White                FFFFFF f
# 18  17   Light Green          C2DAB8 f
# 19  18   Light Yellow         FBE696 f
# 20  19   Tan                  E4CD9E f
# 21  20   Light Violet         C9CAE2 f
# 22  21   Glow In Dark Opaque  D4D5C9 f
# 23  22   Purple               81007B f
# 24  23   Dark Blue-Violet     2032B0 f
# 25  25   Orange               FE8A18 f
# 26  26   Magenta              923978 f
# 27  27   Lime                 BBE90B f
# 28  28   Dark Tan             958A73 f
# 29  29   Bright Pink          E4ADC8 f
# 30  30   Medium Lavender      AC78BA f
# ⋮   ⋮    ⋮                    ⋮      ⋮
# 175 1059 Trans-Purple Opal    8320B7 t
# 176 1060 Trans-Green Opal     84B68D t
# 177 1061 Trans-Dark Blue Opal 0020A0 t
# 178 1062 Vibrant Yellow       EBD800 f
# 179 1063 Metallic Copper      B46A00 f
# 180 1064 Fabuland Red         FF8014 f
# 181 1065 Reddish Gold         AC8247 f
# 182 1066 Curry                DD982E f
# 183 1067 Dark Nougat          AD6140 f
# 184 1068 Reddish Orange       EE5434 f
# 185 1069 Pearl Red            D60026 f
# 186 1070 Pearl Blue           0059A3 f
# 187 1071 Pearl Green          008E3C f
# 188 1072 Pearl Brown          57392C f
# 189 1073 Pearl Black          0A1327 f
# 190 1074 Duplo Blue           009ECE f
# 191 1076 Duplo Lime           FFF230 f
# 192 1077 Fabuland Lime        78FC78 f
# 193 1078 Duplo Medium Green   468A5F f
# 194 1080 Light Tan            F3C988 f
# 195 1081 Rust Orange          872B17 f
# 196 1082 Clikits Pink         FE78B0 f
# 197 1083 Two-tone Copper      945148 f
# 198 1084 Two-tone Gold        AB673A f
# 199 1085 Two-tone Silver      737271 f
# 200 1086 Pearl Lime           6A7944 f
# 201 1087 Duplo Pink           FF879C f
# 202 1088 Medium Brown         755945 f
# 203 1089 Warm Tan             CCA373 f
# 204 9999 [No Color/Any Color] 05131D f

# %% [markdown]
# ### `07-Which set is missing version 1?`
#
# - Use `filter()` to extract `version` `1` from the inventories table; save the filter to `version_1_inventories`.
# - Use `anti_join` to combine `version_1_inventories` with sets to determine which set is missing a `version` `1`.

# %%
# Use filter() to extract version 1 
version_1_inventories <- inventories %>%
  filter(version == 1)

# Use anti_join() to find which set is missing a version 1
sets %>%
  anti_join(version_1_inventories, by = c("set_num"))
# Out:
#   set_num name                       year theme_id num_parts
# 1 10261-1 Roller Coaster             2018 673      4124
# 2 10875-1 Cargo Train                2018 634       105
# 3 76081-1 The Milano vs. The Abilisk 2017 704       462

# %% [markdown]
# ### `08-Aggregating sets to look at their differences`
#
# - Add a filter for the `"Batman"` theme to create the `batman_colors` object.
# - Add a `fraction` column to `batman_colors` that displays the total divided by the sum of the total.
# - Repeat the steps to filter and aggregate the `"Star Wars"` set data to create the `star_wars_colors` object.
# - Add a `fraction` column to `star_wars_colors` to display the fraction of the total.

# %%
inventory_parts_themes <- inventories %>%
  inner_join(inventory_parts, by = c("id" = "inventory_id")) %>%
  arrange(desc(quantity)) %>%
  select(-id, -version) %>%
  inner_join(sets, by = "set_num") %>%
  inner_join(themes, by = c("theme_id" = "id"), suffix = c("_set", "_theme"))

# %%
batman_colors <- inventory_parts_themes %>%
  # Filter the inventory_parts_themes table for the Batman theme
  filter(name_theme == "Batman") %>%
  group_by(color_id) %>%
  summarize(total = sum(quantity)) %>%
  # Add a fraction column of the total divided by the sum of the total 
  mutate(fraction = total / sum(total))

# Filter and aggregate the Star Wars set data; add a fraction column
star_wars_colors <- inventory_parts_themes %>%
  filter(name_theme == "Star Wars") %>%
  group_by(color_id) %>%
  summarize(total = sum(quantity)) %>%
	mutate(fraction = total / sum(total))

# %%
head(batman_colors,3)
head(star_wars_colors,3)
# Out:
#   color_id total fraction
# 1 0        8799  0.33050370
# 2 1         490  0.01840514
# 3 2         270  0.01014161
#   color_id total fraction
# 1 0        44264 0.184099653
# 2 1         8297 0.034508287
# 3 2         1069 0.004446108

# %% [markdown]
# ### `09-Combining sets`
# - Join the `batman_colors` and `star_wars_colors` tables; be sure to include all observations from both tables.
# - Replace the NAs in the `total_batman` and `total_star_wars` columns.

# %%
batman_colors %>%
  # Join the Batman and Star Wars colors
  full_join(star_wars_colors, by = "color_id", suffix = c("_batman", "_star_wars")) %>%
  # Replace NAs in the total_batman and total_star_wars columns
# 73  334      0                     NA       2            8.318256e-06
# 74  335      0                     NA      24            9.981908e-05
# 75  366      0                     NA       2            8.318256e-06
# 76  383      0                     NA      68            2.828207e-04
# 77  462      0                     NA      30            1.247738e-04
#    name                 rgb    is_trans
# 1  Black                05131D f
# 2  Blue                 0055BF f
# 3  Green                237841 f
# 4  Dark Turquoise       008F9B f
# 5  Red                  C91A09 f
# 6  Dark Pink            C870A0 f
# 7  Bright Green         4B9F4A f
# 8  Yellow               F2CD37 f
# 9  White                FFFFFF f
# 10 Tan                  E4CD9E f
# 11 Orange               FE8A18 f
# 12 Lime                 BBE90B f
# 13 Dark Tan             958A73 f
# 14 Bright Pink          E4ADC8 f
# 15 Trans-Dark Blue      0020A0 t
# 16 Trans-Green          84B68D t
# 17 Trans-Bright Green   D9E4A7 t
# 18 Trans-Red            C91A09 t
# 19 Trans-Black          635F52 t
# 20 Trans-Light Blue     AEEFEC t
# 21 Trans-Neon Green     F8F184 t
# 22 Trans-Yellow         F5CD2F t
# 23 Trans-Clear          FCFCFC t
# 24 Trans-Purple         A5A5CB t
# 25 Trans-Neon Orange    FF800D t
# 26 Reddish Brown        582A12 f
# 27 Light Bluish Gray    A0A5A9 f
# 28 Dark Bluish Gray     6C6E68 f
# 29 Medium Blue          5A93DB f
# 30 Light Nougat         F6D7B3 f
# ⋮  ⋮                    ⋮      ⋮
# 48 Light Aqua           ADC3C0 f
# 49 Olive Green          9B9A5A f
# 50 Sand Green           A0BCAC f
# 51 Sand Blue            6074A1 f
# 52 Dark Orange          A95500 f
# 53 Glow in Dark White   D9D9D9 f
# 54 Coral                FF698F f
# 55 Metallic Copper      B46A00 f
# 56 [No Color/Any Color] 05131D f
# 57 Brown                583927 f
# 58 Light Gray           9BA19D f
# 59 Dark Gray            6D6E5C f
# 60 Light Blue           B4D2E3 f
# 61 Purple               81007B f
# 62 Magenta              923978 f
# 63 Medium Lavender      AC78BA f
# 64 Trans-Dark Pink      DF6695 t
# 65 Metallic Gold        DBAC34 f
# 66 Nougat               D09168 f
# 67 Violet               4354A3 f
# 68 Speckle Black-Silver 05131D f
# 69 Copper               AE7A59 f
# 70 Metal Blue           7988A1 f
# 71 Bright Light Blue    9FC3E9 f
# 72 Sky Blue             7DBFDD f
# 73 Chrome Gold          BBA53D f
# 74 Sand Red             D67572 f
# 75 Earth Orange         FA9C1C f
# 76 Chrome Silver        E0E0E0 f
# 77 Medium Orange        FFA70B f

# %% [markdown]
# - Join the `batman_colors` and `star_wars_colors` tables; be sure to include all observations from both tables.
# - Replace the NAs in the `total_batman` and `total_star_wars` columns.

# %%
batman_colors %>%
  full_join(star_wars_colors, by = "color_id", suffix = c("_batman", "_star_wars")) %>%
  replace_na(list(total_batman = 0, total_star_wars = 0)) %>%
  inner_join(colors, by = c("color_id" = "id")) %>%
  # Create the difference and total columns
  mutate(difference = fraction_batman - fraction_star_wars,
         total = total_batman + total_star_wars) %>%
  # Filter for totals greater than 200
  filter(total >= 200)
# 17 Trans-Neon Green     F8F184 t         1.857777e-03   416
# 18 Trans-Yellow         F5CD2F t         1.263103e-02   815
# 19 Trans-Clear          FCFCFC t         3.764111e-03  1683
# 20 Trans-Neon Orange    FF800D t        -1.009783e-03   634
# 21 Reddish Brown        582A12 f        -8.176149e-03  7503
# 22 Light Bluish Gray    A0A5A9 f        -7.801580e-02 57227
# 23 Dark Bluish Gray     6C6E68 f        -1.140525e-02 44923
# 24 Metallic Silver      A5A9B4 f        -1.090746e-03   503
# 25 Medium Nougat        AA7D55 f         4.284469e-03   304
# 26 Pearl Dark Gray      575857 f         4.616663e-03   505
# 27 Flat Silver          898788 f         1.508129e-02  2202
# 28 Trans-Orange         F08F1C t         4.601688e-03   960
# 29 Dark Blue            0A3463 f        -2.752447e-03  2989
# 30 Dark Green           184632 f        -3.132877e-04   938
# 31 Pearl Gold           AA7F2E f         6.740644e-03   536
# 32 Dark Brown           352100 f         1.645274e-03   437
# 33 Dark Red             720E0F f        -1.699217e-02  4888
# 34 Olive Green          9B9A5A f        -2.517665e-04   211
# 35 Sand Green           A0BCAC f        -3.158241e-03  1291
# 36 Sand Blue            6074A1 f        -2.431926e-03   675
# 37 Dark Orange          A95500 f         1.013862e-03   649
# 38 [No Color/Any Color] 05131D f         1.185053e-03   337
# 39 Brown                583927 f                   NA   901
# 40 Light Gray           9BA19D f                   NA  5485
# 41 Dark Gray            6D6E5C f                   NA  3836

# %% [markdown]
# ### `10-Visualizing the difference: Batman and Star Wars`
# - Create a bar plot using the `colors_joined` table to display the most prominent colors in the Batman and Star Wars themes, with the bars colored by their `name`.

# %%
library(forcats)

colors_joined <- batman_colors %>%
  full_join(star_wars_colors, by = "color_id", suffix = c("_batman", "_star_wars")) %>%
  replace_na(list(total_batman = 0, total_star_wars = 0)) %>%
  inner_join(colors, by = c("color_id" = "id")) %>%
  mutate(difference = fraction_batman - fraction_star_wars,
         total = total_batman + total_star_wars) %>%
  filter(total >= 200) %>%
  mutate(name = fct_reorder(name, difference)) 

head(colors_joined,3)
# Out:
#   color_id total_batman fraction_batman total_star_wars fraction_star_wars
# 1 0        8799         0.33050370      44264           0.184099653
# 2 1         490         0.01840514       8297           0.034508287
# 3 2         270         0.01014161       1069           0.004446108
#   name  rgb    is_trans difference   total
# 1 Black 05131D f         0.146404047 53063
# 2 Blue  0055BF f        -0.016103149  8787
# 3 Green 237841 f         0.005695499  1339

# %%
# we need to add # to create our palette
colors_joined$rgb <- paste("#", colors_joined$rgb, sep="")
color_palette <- setNames(colors_joined$rgb, colors_joined$name)

# %%
library(ggplot2)
# Create a bar plot using colors_joined and the name and difference columns
png(filename="..\\05_Joining_Data_with_dplyr\\result.png")
plot(ggplot(colors_joined, aes(name, difference, fill = name)) +
  geom_col() +
  coord_flip() +
  scale_fill_manual(values = color_palette, guide = "none") +
  labs(y = "Difference: Batman - Star Wars"))
dev.off()
# Out:
# Warning message:
# "Removed 3 rows containing missing values (position_stack)."
# png
#   2

# %% [markdown]
# ### `The End`
